# %%
# Dependencies
import requests
from config import api_key
import pandas as pd
import csv
from pprint import pprint

year = 2022
numb = 1
url = f"https://api.themoviedb.org/3/discover/movie?api_key={api_key}&page={numb}&primary_release_year={year}&sort_by=revenue.desc'"

# %%
tmdb = requests.get(url).json()

# %%
tmdb_df1 =pd.json_normalize(tmdb, 'results')
tmbd_df= pd.DataFrame(tmdb_df1)
tmbd_df
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 0   False  /73IO5kd6cohhMW9qDo9i8geI0Wc.jpg                 [18]   32881
# 1   False  /mqsPyyeDCBAghXyjbw4TfEYwljw.jpg      [10752, 18, 28]   49046
# 2   False  /cL0cdccOMzM508ODsWPfHVMMAzo.jpg                 [28]  267805
# 3   False                              None          [10749, 18]  269579
# 4   False                              None             [99, 36]  224291
# 5   False                              None          [35, 10402]   82527
# 6   False  /16AAQwep17gjOsyZQLBklIUp6BE.jpg     [18, 10749, 878]  400291
# 7   False  /21Pj94MOsW5708QTSwRZea8ddfo.jpg        [28, 878, 53]  425906
# 8   False  /8mDJ1GqqVgbvYYeaZzbyMCMG78Q.jpg          [99, 10402]  396194
# 9   False                              None                 [99]  428937
# 10  False  /rgZ3hdzgMgYgzvBfwNEVW01bpK1.jpg         [28, 53, 18]  429473
# 11  False  /nHtA1qMOzm2T50B99h0UXR4V3KC.jpg      [10752, 18, 36]  399178
# ...

# %%
numb = numb 1
url = f"https://api.themoviedb.org/3/discover/movie?api_key={api_key}&page={numb}&primary_release_year={year}&sort_by=revenue.desc'"


tmdb_page = requests.get(url).json()
# Out:
# {'page': 2,
#  'results': [{'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 308299,
#    'original_language': 'en',
#    'original_title': 'Black Sabbath: Master of Reality Documentary',
#    'overview': "The documentary follows Black Sabbath as they release their iconic album Paranoid through the recording and releasing of their album Master of Reality. Sharing many known and unknown facts about the band's lives in 1971 and 1972.",
#    'popularity': 0.73,
#    'poster_path': '/elCPmmjrEvwHEqCETxphPluC3nU.jpg',
#    'release_date': '2022-05-04',
#    'title': 'Black Sabbath: Master of Reality Documentary',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 311271,
#    'original_language': 'en',
#    'original_title': "America's Most Haunted Town",
# ...

# %%
tmdb_pages_df = pd.DataFrame.from_dict(pd.json_normalize(tmdb), orient='columns')
middle_dataframe = middle_dataframe.append(df_temp)

# %%
tmdb_df2 =pd.json_normalize(tmdb_page, 'results')
tmbd_page_df= pd.DataFrame(tmdb_df2)
tmbd_page_df
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False                              None                     [99]  308299
# 1   False                              None                       []  311271
# 2   False  /o3U4733mGsmieBeqs4Sw2ze6n53.jpg      [14, 18, 10749, 36]  245842
# 3   False                              None                  [10749]  308059
# 4   False  /8XD7eIkIGHJor6Wv11GXc3Dxj3q.jpg                 [18, 53]  339754
# 5   False                              None         [14, 80, 35, 27]  351064
# 6   False  /sXnvnDIfOia6dnMR3ZuqBSGNdpd.jpg             [53, 28, 27]  298028
# 7   False  /sB4Qee1z6Mkood7WNdUJSJJF0s0.jpg                     [18]  301502
# 8   False                              None              [10402, 99]  376809
# 9   False  /AaV1YIdWKnjAIAOe8UUKBFm327v.jpg                 [28, 18]  361743
# 10  False  /92PJmMopfy64VYjd0HvIQaHGZX0.jpg      [10751, 35, 16, 28]  366672
# ...

# %%
tmdb_df = tmbd_df.append([tmbd_page_df],ignore_index=False)
tmdb_df
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_3952\3921284101.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmdb_df = tmbd_df.append([tmbd_page_df],ignore_index=False)
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /73IO5kd6cohhMW9qDo9i8geI0Wc.jpg                     [18]   32881
# 1   False  /mqsPyyeDCBAghXyjbw4TfEYwljw.jpg          [10752, 18, 28]   49046
# 2   False  /cL0cdccOMzM508ODsWPfHVMMAzo.jpg                     [28]  267805
# 3   False                              None              [10749, 18]  269579
# 4   False                              None                 [99, 36]  224291
# 5   False                              None              [35, 10402]   82527
# 6   False  /16AAQwep17gjOsyZQLBklIUp6BE.jpg         [18, 10749, 878]  400291
# 7   False  /21Pj94MOsW5708QTSwRZea8ddfo.jpg            [28, 878, 53]  425906
# ...

# %%
url_tv = f"https://api.themoviedb.org/3/tv/popular?api_key={api_key}&page={numb}"

tvlist = requests.get(url).json()
pprint(tvlist)
