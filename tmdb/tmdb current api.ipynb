# %%
# Dependencies
import requests
import pandas as pd
import numpy as np
import csv
from pprint import pprint

api_key = "6dc05d92f2124269dc57ec76b2176741"
# please don't overuse the API - it's free, but if there are too many requests, they can cut off my API.  Once we have the data, you can play all you want with it, or you can create your own.  DK

#setting year
year = 2017

# setting page number to 1
numb = 1

# base query
# url = f"https://api.themoviedb.org/3/discover/movie?api_key={api_key}&page={numb}&primary_release_year={year}&sort_by=revenue.desc'"
# url2 = f"https://api.themoviedb.org/3/movie/449627?api_key={api_key}"


url = f"https://api.themoviedb.org/3/discover/movie?api_key={api_key}&page={numb}&sort_by=popularity.desc&include_adult=false&include_video=false&page=1&year={year}&with_watch_providers=netflix&with_watch_monetization_types=flatrate"




#tmdb only displays 20 results per page, and each page must be a separate request, so we 
# must loop the requests by the number of pages in the result

# %%
# https://api.themoviedb.org/3/discover/movie?api_key=<<api_key>>&language=de-DE&region=DE&release_date.gte=2016-11-16&release_date.lte=2016-12-02&with_release_type=2|3


# https://api.themoviedb.org/3/discover/movie?api_key=<<api_key>>&sort_by=popularity.desc&include_adult=false&include_video=false&page=1&year=2022&with_watch_providers=netflix&with_watch_monetization_types=flatrate

# requesting first page
tmdb = requests.get(url).json()
pprint(tmdb)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [10749],
#               'id': 485470,
#               'original_language': 'ko',
#               'original_title': '착한 형수2',
#               'overview': 'If you give it once, a good brother-in-law who '
#                           'gives everything generously will come!  At the '
#                           'house of her girlfriend Jin-kyung, who lives with '
#                           'pumice stone, her brother and his wife suddenly '
#                           'visit and the four of them live together. At first, '
#                           "Kyung-seok, who was burdened by his girlfriend's "
#                           'brother, began to keep his eyes on his wife, '
#                           'Yeon-su. A bold brother-in-law who walks around in '
#                           'no-bra and panties without hesitation even at his '
#                           "sister-in-law's house. Besides, from a certain "
#                           'moment, he starts to send a hand of temptation to '
#                           'Pyeong-seok first...',
#               'popularity': 1515.469,
#               'poster_path': '/3pEs4hmeHvTAsmx09whEaPDOQpq.jpg',
#               'release_date': '2017-10-08',
#               'title': 'Nice Sister-In-Law 2',
#               'video': False,
#               'vote_average': 6,
#               'vote_count': 2},
#              {'adult': False,
#               'backdrop_path': '/7OxGhxUYAdtuike29VMzEFxJx7y.jpg',
#               'genre_ids': [35, 14],
#               'id': 2907,
#               'original_language': 'en',
#               'original_title': 'The Addams Family',
#               'overview': 'When a man claiming to be long-lost Uncle Fester '
#                           'reappears after 25 years lost, the family plans a '
#                           'celebration to wake the dead. But the kids barely '
#                           'have time to warm up the electric chair before '
#                           'Morticia begins to suspect Fester is fraud when he '
#                           "can't recall any of the details of Fester's life.",
#               'popularity': 413.417,
#               'poster_path': '/qFf8anju5f2epI0my8RdwwIXFIP.jpg',
#               'release_date': '1991-11-22',
#               'title': 'The Addams Family',
#               'video': False,
#               'vote_average': 7,
#               'vote_count': 3804},
#              {'adult': False,
#               'backdrop_path': '/naNXYdBzTEb1KwOdi1RbBkM9Zv1.jpg',
#               'genre_ids': [27, 53],
#               'id': 420634,
#               'original_language': 'en',
#               'original_title': 'Terrifier',
#               'overview': 'On Halloween night, a young woman finds herself as '
#                           'the obsession of a sadistic murderer known as Art '
#                           'the Clown.',
#               'popularity': 295.279,
#               'poster_path': '/4lwh4MX2yCogHflyAYMRbfdnpnm.jpg',
#               'release_date': '2016-03-15',
#               'title': 'Terrifier',
#               'video': False,
#               'vote_average': 6.6,
#               'vote_count': 1117},
#              {'adult': False,
#               'backdrop_path': '/qkt1Qn9j6yw9rcJhvSu1p3wuiBm.jpg',
#               'genre_ids': [10751, 35, 14],
#               'id': 8871,
#               'original_language': 'en',
#               'original_title': 'How the Grinch Stole Christmas',
#               'overview': 'Inside a snowflake exists the magical land of '
#                           'Whoville. In Whoville, live the Whos, an almost '
#                           'mutated sort of Munchkin-like people. All the Whos '
#                           'love Christmas, yet just outside of their beloved '
#                           'Whoville lives the Grinch. The Grinch is a nasty '
#                           'creature that hates Christmas, and plots to steal '
#                           'it away from the Whos, whom he equally abhors. Yet '
#                           'a small child, Cindy Lou Who, decides to try '
#                           'befriending the Grinch.',
#               'popularity': 289.345,
#               'poster_path': '/1WZbbPApEivA421gCOluuzMMKCk.jpg',
#               'release_date': '2000-11-15',
#               'title': 'How the Grinch Stole Christmas',
#               'video': False,
#               'vote_average': 6.7,
#               'vote_count': 6190},
#              {'adult': False,
#               'backdrop_path': '/t3LicFpYHeYpwqm7L5wDpd22hL5.jpg',
#               'genre_ids': [12, 14],
#               'id': 671,
#               'original_language': 'en',
#               'original_title': "Harry Potter and the Philosopher's Stone",
#               'overview': 'Harry Potter has lived under the stairs at his aunt '
#                           "and uncle's house his whole life. But on his 11th "
#                           "birthday, he learns he's a powerful wizard—with a "
#                           'place waiting for him at the Hogwarts School of '
#                           'Witchcraft and Wizardry. As he learns to harness '
#                           "his newfound powers with the help of the school's "
#                           'kindly headmaster, Harry uncovers the truth about '
#                           "his parents' deaths—and about the villain who's to "
#                           'blame.',
#               'popularity': 223.77,
#               'poster_path': '/wuMc08IPKEatf9rnMNXvIDxqP4W.jpg',
#               'release_date': '2001-11-16',
#               'title': "Harry Potter and the Philosopher's Stone",
#               'video': False,
#               'vote_average': 7.9,
#               'vote_count': 23632},
#              {'adult': False,
#               'backdrop_path': '/1stUIsjawROZxjiCMtqqXqgfZWC.jpg',
#               'genre_ids': [12, 14],
#               'id': 672,
#               'original_language': 'en',
#               'original_title': 'Harry Potter and the Chamber of Secrets',
#               'overview': 'Cars fly, trees fight back, and a mysterious '
#                           'house-elf comes to warn Harry Potter at the start '
#                           'of his second year at Hogwarts. Adventure and '
#                           'danger await when bloody writing on a wall '
#                           'announces: The Chamber Of Secrets Has Been Opened. '
#                           'To save Hogwarts will require all of Harry, Ron and '
#                           'Hermione’s magical abilities and courage.',
#               'popularity': 203.984,
#               'poster_path': '/sdEOH0992YZ0QSxgXNIGLq1ToUi.jpg',
#               'release_date': '2002-11-13',
#               'title': 'Harry Potter and the Chamber of Secrets',
#               'video': False,
#               'vote_average': 7.7,
#               'vote_count': 18983},
#              {'adult': False,
#               'backdrop_path': '/urDWNffjwmNi5IQaezw9GwqkUXa.jpg',
#               'genre_ids': [12, 14],
#               'id': 767,
#               'original_language': 'en',
#               'original_title': 'Harry Potter and the Half-Blood Prince',
#               'overview': 'As Lord Voldemort tightens his grip on both the '
#                           'Muggle and wizarding worlds, Hogwarts is no longer '
#                           'a safe haven. Harry suspects perils may even lie '
#                           'within the castle, but Dumbledore is more intent '
#                           'upon preparing him for the final battle fast '
#                           'approaching. Together they work to find the key to '
#                           'unlock Voldemorts defenses and to this end, '
#                           'Dumbledore recruits his old friend and colleague '
#                           'Horace Slughorn, whom he believes holds crucial '
#                           'information. Even as the decisive showdown looms, '
#                           'romance blossoms for Harry, Ron, Hermione and their '
#                           'classmates. Love is in the air, but danger lies '
#                           'ahead and Hogwarts may never be the same again.',
#               'popularity': 203.954,
#               'poster_path': '/z7uo9zmQdQwU5ZJHFpv2Upl30i1.jpg',
#               'release_date': '2009-07-07',
#               'title': 'Harry Potter and the Half-Blood Prince',
#               'video': False,
#               'vote_average': 7.7,
#               'vote_count': 16829},
#              {'adult': False,
#               'backdrop_path': '/5rrGVmRUuCKVbqUu41XIWTXJmNA.jpg',
#               'genre_ids': [12, 14, 10751],
#               'id': 674,
#               'original_language': 'en',
#               'original_title': 'Harry Potter and the Goblet of Fire',
#               'overview': "When Harry Potter's name emerges from the Goblet of "
#                           'Fire, he becomes a competitor in a grueling battle '
#                           'for glory among three wizarding schools—the '
#                           'Triwizard Tournament. But since Harry never '
#                           'submitted his name for the Tournament, who did? Now '
#                           'Harry must confront a deadly dragon, fierce water '
#                           'demons and an enchanted maze only to find himself '
#                           'in the cruel grasp of He Who Must Not Be Named.',
#               'popularity': 196.642,
#               'poster_path': '/fECBtHlr0RB3foNHDiCBXeg9Bv9.jpg',
#               'release_date': '2005-11-16',
#               'title': 'Harry Potter and the Goblet of Fire',
#               'video': False,
#               'vote_average': 7.8,
#               'vote_count': 17960},
#              {'adult': False,
#               'backdrop_path': '/obKmfNexgL4ZP5cAmzdL4KbHHYX.jpg',
#               'genre_ids': [12, 14],
#               'id': 673,
#               'original_language': 'en',
#               'original_title': 'Harry Potter and the Prisoner of Azkaban',
#               'overview': 'Year three at Hogwarts means new fun and challenges '
#                           'as Harry learns the delicate art of approaching a '
#                           'Hippogriff, transforming shape-shifting Boggarts '
#                           'into hilarity and even turning back time. But the '
#                           'term also brings danger: soul-sucking Dementors '
#                           'hover over the school, an ally of the accursed '
#                           'He-Who-Cannot-Be-Named lurks within the castle '
#                           'walls, and fearsome wizard Sirius Black escapes '
#                           'Azkaban. And Harry will confront them all.',
#               'popularity': 180.313,
#               'poster_path': '/aWxwnYoe8p2d2fcxOqtvAtJ72Rw.jpg',
#               'release_date': '2004-05-31',
#               'title': 'Harry Potter and the Prisoner of Azkaban',
#               'video': False,
#               'vote_average': 8,
#               'vote_count': 18664},
#              {'adult': False,
#               'backdrop_path': '/1n00NlOGRFZVs8coBxyZLm5l4EC.jpg',
#               'genre_ids': [28, 12, 878],
#               'id': 335988,
#               'original_language': 'en',
#               'original_title': 'Transformers: The Last Knight',
#               'overview': 'Autobots and Decepticons are at war, with humans on '
#                           'the sidelines. Optimus Prime is gone. The key to '
#                           'saving our future lies buried in the secrets of the '
#                           'past, in the hidden history of Transformers on '
#                           'Earth.',
#               'popularity': 178.4,
#               'poster_path': '/s5HQf2Gb3lIO2cRcFwNL9sn1o1o.jpg',
#               'release_date': '2017-06-16',
#               'title': 'Transformers: The Last Knight',
#               'video': False,
#               'vote_average': 6,
#               'vote_count': 5236},
#              {'adult': False,
#               'backdrop_path': '/n5A7brJCjejceZmHyujwUTVgQNC.jpg',
#               'genre_ids': [14, 12],
#               'id': 12445,
#               'original_language': 'en',
#               'original_title': 'Harry Potter and the Deathly Hallows: Part 2',
#               'overview': 'Harry, Ron and Hermione continue their quest to '
#                           'vanquish the evil Voldemort once and for all. Just '
#                           'as things begin to look hopeless for the young '
#                           'wizards, Harry discovers a trio of magical objects '
#                           "that endow him with powers to rival Voldemort's "
#                           'formidable skills.',
#               'popularity': 174.805,
#               'poster_path': '/c54HpQmuwXjHq2C9wmoACjxoom3.jpg',
#               'release_date': '2011-07-07',
#               'title': 'Harry Potter and the Deathly Hallows: Part 2',
#               'video': False,
#               'vote_average': 8.1,
#               'vote_count': 17963},
#              {'adult': False,
#               'backdrop_path': '/askg3SMvhqEl4OL52YuvdtY40Yb.jpg',
#               'genre_ids': [10751, 16, 14, 10402, 35, 12],
#               'id': 354912,
#               'original_language': 'en',
#               'original_title': 'Coco',
#               'overview': 'Despite his family’s baffling generations-old ban '
#                           'on music, Miguel dreams of becoming an accomplished '
#                           'musician like his idol, Ernesto de la Cruz. '
#                           'Desperate to prove his talent, Miguel finds himself '
#                           'in the stunning and colorful Land of the Dead '
#                           'following a mysterious chain of events. Along the '
#                           'way, he meets charming trickster Hector, and '
#                           'together, they set off on an extraordinary journey '
#                           "to unlock the real story behind Miguel's family "
#                           'history.',
#               'popularity': 166.068,
#               'poster_path': '/gGEsBPAijhVUFoiNpgZXqRVWJt2.jpg',
#               'release_date': '2017-10-27',
#               'title': 'Coco',
#               'video': False,
#               'vote_average': 8.2,
#               'vote_count': 16554},
#              {'adult': False,
#               'backdrop_path': '/sO2VWeJ8qagNtYoznyLRL8TeSkw.jpg',
#               'genre_ids': [12, 14, 9648],
#               'id': 675,
#               'original_language': 'en',
#               'original_title': 'Harry Potter and the Order of the Phoenix',
#               'overview': 'Returning for his fifth year of study at Hogwarts, '
#                           'Harry is stunned to find that his warnings about '
#                           'the return of Lord Voldemort have been ignored. '
#                           'Left with no choice, Harry takes matters into his '
#                           'own hands, training a small group of students to '
#                           'defend themselves against the dark arts.',
#               'popularity': 159.147,
#               'poster_path': '/5aOyriWkPec0zUDxmHFP9qMmBaj.jpg',
#               'release_date': '2007-06-28',
#               'title': 'Harry Potter and the Order of the Phoenix',
#               'video': False,
#               'vote_average': 7.7,
#               'vote_count': 16993},
#              {'adult': False,
#               'backdrop_path': '/rshlQ6LfPRSWFhpGL4s5ZkIPR51.jpg',
#               'genre_ids': [18, 36, 10752],
#               'id': 324786,
#               'original_language': 'en',
#               'original_title': 'Hacksaw Ridge',
#               'overview': 'WWII American Army Medic Desmond T. Doss, who '
#                           'served during the Battle of Okinawa, refuses to '
#                           'kill people and becomes the first Conscientious '
#                           'Objector in American history to receive the '
#                           'Congressional Medal of Honor.',
#               'popularity': 156.813,
#               'poster_path': '/jhWbYeUNOA5zAb6ufK6pXQFXqTX.jpg',
#               'release_date': '2016-10-07',
#               'title': 'Hacksaw Ridge',
#               'video': False,
#               'vote_average': 8.2,
#               'vote_count': 11663},
#              {'adult': False,
#               'backdrop_path': '/vcrgU0KaNj5mKUCIQSUdiQwTE9y.jpg',
#               'genre_ids': [12, 14],
#               'id': 12444,
#               'original_language': 'en',
#               'original_title': 'Harry Potter and the Deathly Hallows: Part 1',
#               'overview': 'Harry, Ron and Hermione walk away from their last '
#                           'year at Hogwarts to find and destroy the remaining '
#                           "Horcruxes, putting an end to Voldemort's bid for "
#                           "immortality. But with Harry's beloved Dumbledore "
#                           "dead and Voldemort's unscrupulous Death Eaters on "
#                           'the loose, the world is more dangerous than ever.',
#               'popularity': 156.742,
#               'poster_path': '/iGoXIpQb7Pot00EEdwpwPajheZ5.jpg',
#               'release_date': '2010-10-06',
#               'title': 'Harry Potter and the Deathly Hallows: Part 1',
#               'video': False,
#               'vote_average': 7.8,
#               'vote_count': 16649},
#              {'adult': False,
#               'backdrop_path': '/rAiYTfKGqDCRIIqo664sY9XZIvQ.jpg',
#               'genre_ids': [12, 18, 878],
#               'id': 157336,
#               'original_language': 'en',
#               'original_title': 'Interstellar',
#               'overview': 'The adventures of a group of explorers who make use '
#                           'of a newly discovered wormhole to surpass the '
#                           'limitations on human space travel and conquer the '
#                           'vast distances involved in an interstellar voyage.',
#               'popularity': 129.328,
#               'poster_path': '/gEU2QniE6E77NI6lCU6MxlNBvIx.jpg',
#               'release_date': '2014-11-05',
#               'title': 'Interstellar',
#               'video': False,
#               'vote_average': 8.4,
#               'vote_count': 29891},
#              {'adult': False,
#               'backdrop_path': '/aJn9XeesqsrSLKcHfHP4u5985hn.jpg',
#               'genre_ids': [12, 28, 878],
#               'id': 283995,
#               'original_language': 'en',
#               'original_title': 'Guardians of the Galaxy Vol. 2',
#               'overview': 'The Guardians must fight to keep their newfound '
#                           'family together as they unravel the mysteries of '
#                           "Peter Quill's true parentage.",
#               'popularity': 126.15,
#               'poster_path': '/y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg',
#               'release_date': '2017-04-19',
#               'title': 'Guardians of the Galaxy Vol. 2',
#               'video': False,
#               'vote_average': 7.6,
#               'vote_count': 18981},
#              {'adult': False,
#               'backdrop_path': '/vHJlbhsXrZ5yrO2KqCbGSIU6fRX.jpg',
#               'genre_ids': [28, 9648, 878, 53],
#               'id': 198663,
#               'original_language': 'en',
#               'original_title': 'The Maze Runner',
#               'overview': 'Set in a post-apocalyptic world, young Thomas is '
#                           'deposited in a community of boys after his memory '
#                           "is erased, soon learning they're all trapped in a "
#                           'maze that will require him to join forces with '
#                           'fellow “runners” for a shot at escape.',
#               'popularity': 124.144,
#               'poster_path': '/ode14q7WtDugFDp78fo9lCsmay9.jpg',
#               'release_date': '2014-09-10',
#               'title': 'The Maze Runner',
#               'video': False,
#               'vote_average': 7.2,
#               'vote_count': 15104},
#              {'adult': False,
#               'backdrop_path': '/r17jFHAemzcWPPtoO0UxjIX0xas.jpg',
#               'genre_ids': [28, 53, 80],
#               'id': 324552,
#               'original_language': 'en',
#               'original_title': 'John Wick: Chapter 2',
#               'overview': 'John Wick is forced out of retirement by a former '
#                           'associate looking to seize control of a shadowy '
#                           'international assassins’ guild. Bound by a blood '
#                           'oath to aid him, Wick travels to Rome and does '
#                           'battle against some of the world’s most dangerous '
#                           'killers.',
#               'popularity': 123.639,
#               'poster_path': '/kL99FVq572hNPfMyfQCT7tGFNeQ.jpg',
#               'release_date': '2017-02-08',
#               'title': 'John Wick: Chapter 2',
#               'video': False,
#               'vote_average': 7.3,
#               'vote_count': 10671},
#              {'adult': False,
#               'backdrop_path': '/3WjbxaqYB4vAbdUfdr5vbglD2JZ.jpg',
#               'genre_ids': [18, 10749],
#               'id': 597,
#               'original_language': 'en',
#               'original_title': 'Titanic',
#               'overview': '101-year-old Rose DeWitt Bukater tells the story of '
#                           'her life aboard the Titanic, 84 years later. A '
#                           'young Rose boards the ship with her mother and '
#                           'fiancé. Meanwhile, Jack Dawson and Fabrizio De '
#                           'Rossi win third-class tickets aboard the ship. Rose '
#                           "tells the whole story from Titanic's departure "
#                           'through to its death—on its first and last '
#                           'voyage—on April 15, 1912.',
#               'popularity': 118.126,
#               'poster_path': '/9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg',
#               'release_date': '1997-11-18',
#               'title': 'Titanic',
#               'video': False,
#               'vote_average': 7.9,
#               'vote_count': 21851}],
#  'total_pages': 1486,
#  'total_results': 29718}

# %%
# # normalizing JSON, converting to datafram
tmdb_df1 =pd.json_normalize(tmdb, 'results')
tmdb_df= pd.DataFrame(tmdb_df1)
tmdb_df
# Out:
#     adult                     backdrop_path                       genre_ids  \
# 0   False                              None                         [10749]
# 1   False  /7OxGhxUYAdtuike29VMzEFxJx7y.jpg                        [35, 14]
# 2   False  /naNXYdBzTEb1KwOdi1RbBkM9Zv1.jpg                        [27, 53]
# 3   False  /qkt1Qn9j6yw9rcJhvSu1p3wuiBm.jpg                 [10751, 35, 14]
# 4   False  /t3LicFpYHeYpwqm7L5wDpd22hL5.jpg                        [12, 14]
# 5   False  /1stUIsjawROZxjiCMtqqXqgfZWC.jpg                        [12, 14]
# 6   False  /urDWNffjwmNi5IQaezw9GwqkUXa.jpg                        [12, 14]
# 7   False  /5rrGVmRUuCKVbqUu41XIWTXJmNA.jpg                 [12, 14, 10751]
# 8   False  /obKmfNexgL4ZP5cAmzdL4KbHHYX.jpg                        [12, 14]
# 9   False  /1n00NlOGRFZVs8coBxyZLm5l4EC.jpg                   [28, 12, 878]
# 10  False  /n5A7brJCjejceZmHyujwUTVgQNC.jpg                        [14, 12]
# 11  False  /askg3SMvhqEl4OL52YuvdtY40Yb.jpg  [10751, 16, 14, 10402, 35, 12]
# 12  False  /sO2VWeJ8qagNtYoznyLRL8TeSkw.jpg                  [12, 14, 9648]
# 13  False  /rshlQ6LfPRSWFhpGL4s5ZkIPR51.jpg                 [18, 36, 10752]
# 14  False  /vcrgU0KaNj5mKUCIQSUdiQwTE9y.jpg                        [12, 14]
# 15  False  /rAiYTfKGqDCRIIqo664sY9XZIvQ.jpg                   [12, 18, 878]
# 16  False  /aJn9XeesqsrSLKcHfHP4u5985hn.jpg                   [12, 28, 878]
# 17  False  /vHJlbhsXrZ5yrO2KqCbGSIU6fRX.jpg             [28, 9648, 878, 53]
# 18  False  /r17jFHAemzcWPPtoO0UxjIX0xas.jpg                    [28, 53, 80]
# 19  False  /3WjbxaqYB4vAbdUfdr5vbglD2JZ.jpg                     [18, 10749]
#
#         id original_language                                original_title  \
# 0   485470                ko                                        착한 형수2
# 1     2907                en                             The Addams Family
# 2   420634                en                                     Terrifier
# 3     8871                en                How the Grinch Stole Christmas
# 4      671                en      Harry Potter and the Philosopher's Stone
# 5      672                en       Harry Potter and the Chamber of Secrets
# 6      767                en        Harry Potter and the Half-Blood Prince
# 7      674                en           Harry Potter and the Goblet of Fire
# 8      673                en      Harry Potter and the Prisoner of Azkaban
# 9   335988                en                 Transformers: The Last Knight
# 10   12445                en  Harry Potter and the Deathly Hallows: Part 2
# 11  354912                en                                          Coco
# 12     675                en     Harry Potter and the Order of the Phoenix
# 13  324786                en                                 Hacksaw Ridge
# 14   12444                en  Harry Potter and the Deathly Hallows: Part 1
# 15  157336                en                                  Interstellar
# 16  283995                en                Guardians of the Galaxy Vol. 2
# 17  198663                en                               The Maze Runner
# 18  324552                en                          John Wick: Chapter 2
# 19     597                en                                       Titanic
#
#                                              overview  popularity  \
# 0   If you give it once, a good brother-in-law who...    1515.469
# 1   When a man claiming to be long-lost Uncle Fest...     413.417
# 2   On Halloween night, a young woman finds hersel...     295.279
# 3   Inside a snowflake exists the magical land of ...     289.345
# 4   Harry Potter has lived under the stairs at his...     223.770
# 5   Cars fly, trees fight back, and a mysterious h...     203.984
# 6   As Lord Voldemort tightens his grip on both th...     203.954
# 7   When Harry Potter's name emerges from the Gobl...     196.642
# 8   Year three at Hogwarts means new fun and chall...     180.313
# 9   Autobots and Decepticons are at war, with huma...     178.400
# 10  Harry, Ron and Hermione continue their quest t...     174.805
# 11  Despite his family’s baffling generations-old ...     166.068
# 12  Returning for his fifth year of study at Hogwa...     159.147
# 13  WWII American Army Medic Desmond T. Doss, who ...     156.813
# 14  Harry, Ron and Hermione walk away from their l...     156.742
# 15  The adventures of a group of explorers who mak...     129.328
# 16  The Guardians must fight to keep their newfoun...     126.150
# 17  Set in a post-apocalyptic world, young Thomas ...     124.144
# 18  John Wick is forced out of retirement by a for...     123.639
# 19  101-year-old Rose DeWitt Bukater tells the sto...     118.126
#
#                          poster_path release_date  \
# 0   /3pEs4hmeHvTAsmx09whEaPDOQpq.jpg   2017-10-08
# 1   /qFf8anju5f2epI0my8RdwwIXFIP.jpg   1991-11-22
# 2   /4lwh4MX2yCogHflyAYMRbfdnpnm.jpg   2016-03-15
# 3   /1WZbbPApEivA421gCOluuzMMKCk.jpg   2000-11-15
# 4   /wuMc08IPKEatf9rnMNXvIDxqP4W.jpg   2001-11-16
# 5   /sdEOH0992YZ0QSxgXNIGLq1ToUi.jpg   2002-11-13
# 6   /z7uo9zmQdQwU5ZJHFpv2Upl30i1.jpg   2009-07-07
# 7   /fECBtHlr0RB3foNHDiCBXeg9Bv9.jpg   2005-11-16
# 8   /aWxwnYoe8p2d2fcxOqtvAtJ72Rw.jpg   2004-05-31
# 9   /s5HQf2Gb3lIO2cRcFwNL9sn1o1o.jpg   2017-06-16
# 10  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg   2011-07-07
# 11  /gGEsBPAijhVUFoiNpgZXqRVWJt2.jpg   2017-10-27
# 12  /5aOyriWkPec0zUDxmHFP9qMmBaj.jpg   2007-06-28
# 13  /jhWbYeUNOA5zAb6ufK6pXQFXqTX.jpg   2016-10-07
# 14  /iGoXIpQb7Pot00EEdwpwPajheZ5.jpg   2010-10-06
# 15  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg   2014-11-05
# 16  /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg   2017-04-19
# 17  /ode14q7WtDugFDp78fo9lCsmay9.jpg   2014-09-10
# 18  /kL99FVq572hNPfMyfQCT7tGFNeQ.jpg   2017-02-08
# 19  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg   1997-11-18
#
#                                            title  video  vote_average  \
# 0                           Nice Sister-In-Law 2  False           6.0
# 1                              The Addams Family  False           7.0
# 2                                      Terrifier  False           6.6
# 3                 How the Grinch Stole Christmas  False           6.7
# 4       Harry Potter and the Philosopher's Stone  False           7.9
# 5        Harry Potter and the Chamber of Secrets  False           7.7
# 6         Harry Potter and the Half-Blood Prince  False           7.7
# 7            Harry Potter and the Goblet of Fire  False           7.8
# 8       Harry Potter and the Prisoner of Azkaban  False           8.0
# 9                  Transformers: The Last Knight  False           6.0
# 10  Harry Potter and the Deathly Hallows: Part 2  False           8.1
# 11                                          Coco  False           8.2
# 12     Harry Potter and the Order of the Phoenix  False           7.7
# 13                                 Hacksaw Ridge  False           8.2
# 14  Harry Potter and the Deathly Hallows: Part 1  False           7.8
# 15                                  Interstellar  False           8.4
# 16                Guardians of the Galaxy Vol. 2  False           7.6
# 17                               The Maze Runner  False           7.2
# 18                          John Wick: Chapter 2  False           7.3
# 19                                       Titanic  False           7.9
#
#     vote_count
# 0            2
# 1         3804
# 2         1117
# 3         6190
# 4        23632
# 5        18983
# 6        16829
# 7        17960
# 8        18664
# 9         5236
# 10       17963
# 11       16554
# 12       16993
# 13       11663
# 14       16649
# 15       29891
# 16       18981
# 17       15104
# 18       10671
# 19       21851

# %%
# determining total number of pages in the result
# totalpages = tmdb['total_pages'] + 1
totalpages = 60

for year in range(2017, 2023):

    # looping through all pages
    for numb in range(2, totalpages):

        # resetting url to new page #
        url = f"https://api.themoviedb.org/3/discover/movie?api_key={api_key}&page={numb}&primary_release_year={year}&sort_by=revenue.desc'"
    
        # advancing counter
        numb += 1

        # requesting next page
        tmdb_page = requests.get(url).json()

        # normalizing JSON, converting to datafram
        tmdb_df2 =pd.json_normalize(tmdb_page, 'results')
        tmdb_page= pd.DataFrame(tmdb_df2)
        tmdb_df = pd.concat([tmdb_df, tmdb_page], ignore_index=True)
        # tmdb_page_list.concat(tmdb_page)



    # exporting dataset
    pd.DataFrame(tmdb_df).to_csv(f"tmdb_movie_{year}.csv", encoding='UTF-8')

# %%
tmdb_df.count()
# Out:
# adult                6140
# backdrop_path        3193
# genre_ids            6140
# id                   6140
# original_language    6140
# original_title       6140
# overview             6140
# popularity           6140
# poster_path          5497
# release_date         6140
# title                6140
# video                6140
# vote_average         6140
# vote_count           6140
# dtype: int64

# %%
url_tv = f"https://api.themoviedb.org/3/tv/popular?api_key={api_key}&page={numbtv}"

tvlist = requests.get(url).json()
pprint(tvlist)

# %%
budget = tmdb['budget']
country = tmdb['production_countries']['name']
revenue = tmdb['revenue']
genres = tmdb['genres']['name']



city_data.append({"Budget": budget, 
                    "Revenue": revenue,
                    "Country": country,
                    "Genres": genres})

tmdb_df1 =pd.json_normalize(tmdb)
pd.DataFrame(tmdb_df1).to_csv(f"tmdb_movie_sample.csv", encoding='UTF-8')

tmdb_df1

# %%
yeartv = 2022
numbtv = 1

tmdbtv = requests.get(url).json()

tmdbtv_df1 =pd.json_normalize(tmdbtv, 'results')
tmdbtv_df= pd.DataFrame(tmdbtv_df1)

totalpages = tmdbtv['total_pages']
numb = numb 1
url_tv = f"https://api.themoviedb.org/3/tv/popular?api_key={api_key}&page={numbtv}"

for numb in 1 to 10:
    
    tmdbtv_page = requests.get(url).json()

    tmdbtv_df2 =pd.json_normalize(tmdbtv_page, 'results')
    tmbdtv_page_df= pd.DataFrame(tmdbtv_df2)
    tmbdtv_page_df

    tmdbtv_df = tmbdtv_df.append([tmbdtv_page_df],ignore_index=True)

    numb = numb 1
    url = f"https://api.themoviedb.org/3/discover/movie?api_key={api_key}&page={numb}&primary_release_year={year}&sort_by=revenue.desc'"

pd.DataFrame(tmdb_df).to_csv("tmdb_sample.csv")
