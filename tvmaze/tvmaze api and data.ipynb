# %%
# Dependencies
import requests
from config import api_key
import pandas as pd
import csv


url = f"https://api.tvmaze.com/search/shows?q="

# %%
# Who was the director of the movie Aliens?
movie = requests.get(url + "Stranger").json()
movie
# Out:
# [{'score': 0.8879867,
#   'show': {'id': 28517,
#    'url': 'https://www.tvmaze.com/shows/28517/stranger',
#    'name': 'Stranger',
#    'type': 'Scripted',
#    'language': 'Korean',
#    'genres': ['Crime', 'Thriller', 'Mystery'],
#    'status': 'Ended',
#    'runtime': 90,
#    'averageRuntime': 83,
#    'premiered': '2017-06-10',
#    'ended': '2020-10-04',
#    'officialSite': 'http://program.tving.com/tvn/stranger2',
#    'schedule': {'time': '21:00', 'days': ['Saturday', 'Sunday']},
#    'rating': {'average': 8.1},
#    'weight': 65,
#    'network': {'id': 280,
#     'name': 'tvN',
#     'country': {'name': 'Korea, Republic of',
#      'code': 'KR',
#      'timezone': 'Asia/Seoul'},
#     'officialSite': None},
#    'webChannel': None,
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 324596, 'imdb': 'tt6461346'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/265/662957.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/265/662957.jpg'},
#    'summary': "<p>Though he is rational, a childhood brain surgery leaves prosecutor Hwang Shi Mok to lack emotion. Cold and lonely, he's one of the only prosecutors not involved in corruption. When he meets Police Lieutenant Han Yeo Jin at a murder crime scene, they join forces to eradicate corruption at the prosecutor's office and solve a serial murder case.</p>",
#    'updated': 1647029285,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/28517'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/1914771'}}}},
#  {'score': 0.7000785,
#   'show': {'id': 2993,
#    'url': 'https://www.tvmaze.com/shows/2993/stranger-things',
#    'name': 'Stranger Things',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Horror', 'Science-Fiction'],
#    'status': 'Running',
#    'runtime': None,
#    'averageRuntime': 62,
#    'premiered': '2016-07-15',
#    'ended': None,
#    'officialSite': 'https://www.netflix.com/title/80057281',
#    'schedule': {'time': '', 'days': ['Friday']},
#    'rating': {'average': 8.5},
#    'weight': 100,
#    'network': None,
#    'webChannel': {'id': 1,
#     'name': 'Netflix',
#     'country': None,
#     'officialSite': 'https://www.netflix.com/'},
#    'dvdCountry': None,
#    'externals': {'tvrage': 48493, 'thetvdb': 305288, 'imdb': 'tt4574334'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/396/991288.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/396/991288.jpg'},
#    'summary': "<p>A love letter to the '80s classics that captivated a generation, <b>Stranger Things</b> is set in 1983 Indiana, where a young boy vanishes into thin air. As friends, family and local police search for answers, they are drawn into an extraordinary mystery involving top-secret government experiments, terrifying supernatural forces and one very strange little girl.</p>",
#    'updated': 1667829326,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/2993'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/2209857'}}}},
#  {'score': 0.69735205,
#   'show': {'id': 40648,
#    'url': 'https://www.tvmaze.com/shows/40648/the-stranger',
#    'name': 'The Stranger',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Crime', 'Thriller'],
#    'status': 'Ended',
#    'runtime': None,
#    'averageRuntime': 46,
#    'premiered': '2020-01-30',
#    'ended': '2020-01-30',
#    'officialSite': 'https://www.netflix.com/title/81001209',
#    'schedule': {'time': '', 'days': []},
#    'rating': {'average': 7.3},
#    'weight': 93,
#    'network': None,
#    'webChannel': {'id': 1,
#     'name': 'Netflix',
#     'country': None,
#     'officialSite': 'https://www.netflix.com/'},
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 374977, 'imdb': 'tt9698480'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/271/677727.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/271/677727.jpg'},
#    'summary': "<p><b>The Stranger</b> follows Adam Price as a secret destroys his perfect life, sending him on a collision course with a deadly conspiracy. Price has a good life, two wonderful sons, and a watertight marriage, until one night a stranger sits next to him in a bar and tells him a devastating secret about his wife, Corinne. Soon Adam finds himself tangled in something far darker than even Corinne's deception, and realizes that if he doesn't make exactly the right moves, the conspiracy he's stumbled into will not only ruin lives—it will end them.</p>",
#    'updated': 1618775624,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/40648'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/1772516'}}}},
#  {'score': 0.68813807,
#   'show': {'id': 7367,
#    'url': 'https://www.tvmaze.com/shows/7367/doctor-stranger',
#    'name': 'Doctor Stranger',
#    'type': 'Scripted',
#    'language': 'Korean',
#    'genres': ['Drama', 'Romance', 'Medical'],
#    'status': 'Ended',
#    'runtime': 70,
#    'averageRuntime': 65,
#    'premiered': '2014-05-05',
#    'ended': '2014-07-08',
#    'officialSite': 'http://program.sbs.co.kr/builder/programMainList.do?pgm_id=22000002970',
#    'schedule': {'time': '21:55', 'days': ['Monday', 'Tuesday']},
#    'rating': {'average': 7.9},
#    'weight': 76,
#    'network': {'id': 127,
#     'name': 'SBS',
#     'country': {'name': 'Korea, Republic of',
#      'code': 'KR',
#      'timezone': 'Asia/Seoul'},
#     'officialSite': None},
#    'webChannel': None,
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 280750, 'imdb': 'tt3693414'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/27/68060.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/27/68060.jpg'},
#    'summary': '<p>The series will revolve around Park Hoon, a South Korean who was captured with his father and grows up in North Korea. He is trained to become a genius doctor, and though Park Hoon lands a job at the best South Korean hospital after defecting, he is treated as a foreigner. To find his lost North Korean first love, Song Jae Hee, he does anything to make money.</p>',
#    'updated': 1574971189,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/7367'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/419817'}}}},
#  {'score': 0.66488296,
#   'show': {'id': 43944,
#    'url': 'https://www.tvmaze.com/shows/43944/the-stranger',
#    'name': 'The Stranger',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Thriller'],
#    'status': 'Ended',
#    'runtime': 10,
#    'averageRuntime': 8,
#    'premiered': '2020-04-13',
#    'ended': '2020-04-27',
#    'officialSite': 'https://therokuchannel.roku.com/details/fa715f9d222d5f198e9e5d62255d4b63/the-stranger',
#    'schedule': {'time': '',
#     'days': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']},
#    'rating': {'average': 7.1},
#    'weight': 48,
#    'network': None,
#    'webChannel': {'id': 325,
#     'name': 'Quibi',
#     'country': None,
#     'officialSite': None},
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 376911, 'imdb': 'tt10681780'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/251/627513.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/251/627513.jpg'},
#    'summary': '<p>An unassuming young rideshare driver is thrown into her worst nightmare when a mysterious Hollywood Hills passenger enters her car. Her terrifying, heart-stopping ride with the stranger unfolds over 12 hours as she navigates the seedy underbelly of Los Angeles in a chilling game of cat and mouse.</p>',
#    'updated': 1628841352,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/43944'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/1846826'}}}},
#  {'score': 0.65994334,
#   'show': {'id': 48779,
#    'url': 'https://www.tvmaze.com/shows/48779/hello-stranger',
#    'name': 'Hello Stranger',
#    'type': 'Scripted',
#    'language': 'Tagalog',
#    'genres': ['Drama', 'Romance'],
#    'status': 'Ended',
#    'runtime': 30,
#    'averageRuntime': 20,
#    'premiered': '2020-06-24',
#    'ended': '2020-08-19',
#    'officialSite': 'https://www.youtube.com/channel/UCtI55bOVfu43CatriKvqF_w',
#    'schedule': {'time': '', 'days': ['Wednesday']},
#    'rating': {'average': None},
#    'weight': 44,
#    'network': None,
#    'webChannel': {'id': 21,
#     'name': 'YouTube',
#     'country': None,
#     'officialSite': 'https://www.youtube.com'},
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 384489, 'imdb': None},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/262/655350.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/262/655350.jpg'},
#    'summary': "<p>What if you meet someone who changes your life forever? This is a story about two boys who first met online as strangers who didn't seem to like each other very much but were again brought together by circumstances that would change their lives forever. When Mico organizes an online quiz night with his barkada, he is surprised when the school's popular basketball player, Xavier, joins in and insults them. Little does Mico know that this won't be the last time he'll be seeing Xavier.</p>",
#    'updated': 1641771386,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/48779'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/1891702'}}}},
#  {'score': 0.64020705,
#   'show': {'id': 46232,
#    'url': 'https://www.tvmaze.com/shows/46232/the-stranger',
#    'name': 'The Stranger',
#    'type': 'Scripted',
#    'language': 'English',
#    'genres': ['Drama', 'Science-Fiction'],
#    'status': 'Ended',
#    'runtime': 30,
#    'averageRuntime': 30,
#    'premiered': '1964-04-05',
#    'ended': '1967-08-01',
#    'officialSite': 'https://iview.abc.net.au/show/retrofocus-presents-the-stranger',
#    'schedule': {'time': '18:30', 'days': ['Tuesday']},
#    'rating': {'average': None},
#    'weight': 31,
#    'network': {'id': 114,
#     'name': 'ABC',
#     'country': {'name': 'Australia',
#      'code': 'AU',
#      'timezone': 'Australia/Sydney'},
#     'officialSite': 'https://www.abc.net.au/'},
#    'webChannel': None,
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 307466, 'imdb': 'tt0198246'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/240/602149.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/240/602149.jpg'},
#    'summary': "<p>When a mysterious stranger appears on a family's doorstep, his arrival changes the course of human history.</p>",
#    'updated': 1581669681,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/46232'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/1800893'}}}},
#  {'score': 0.5897355,
#   'show': {'id': 33545,
#    'url': 'https://www.tvmaze.com/shows/33545/hello-stranger',
#    'name': 'Hello Stranger',
#    'type': 'Documentary',
#    'language': 'English',
#    'genres': [],
#    'status': 'Ended',
#    'runtime': 20,
#    'averageRuntime': 20,
#    'premiered': '2016-06-17',
#    'ended': '2016-06-17',
#    'officialSite': 'http://iview.abc.net.au/collection/hello-stranger-real-australian-stories',
#    'schedule': {'time': '', 'days': ['Friday']},
#    'rating': {'average': None},
#    'weight': 14,
#    'network': {'id': 114,
#     'name': 'ABC',
#     'country': {'name': 'Australia',
#      'code': 'AU',
#      'timezone': 'Australia/Sydney'},
#     'officialSite': 'https://www.abc.net.au/'},
#    'webChannel': None,
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 313426, 'imdb': 'tt6038124'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/136/341545.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/136/341545.jpg'},
#    'summary': "<p><b>Hello Stranger</b> is a contemporary snapshot of the people of Australia. We talk to people in the street... then follow one story home. It turns out that we are more complex, remarkable and much stranger than you've ever imagined.</p>",
#    'updated': 1569556970,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/33545'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/1362501'}}}},
#  {'score': 0.57185996,
#   'show': {'id': 32942,
#    'url': 'https://www.tvmaze.com/shows/32942/beyond-stranger-things',
#    'name': 'Beyond Stranger Things',
#    'type': 'Talk Show',
#    'language': 'English',
#    'genres': ['Comedy'],
#    'status': 'Ended',
#    'runtime': None,
#    'averageRuntime': 21,
#    'premiered': '2017-10-27',
#    'ended': '2017-10-27',
#    'officialSite': 'https://www.netflix.com/title/80197912',
#    'schedule': {'time': '', 'days': []},
#    'rating': {'average': 6.3},
#    'weight': 47,
#    'network': None,
#    'webChannel': {'id': 1,
#     'name': 'Netflix',
#     'country': None,
#     'officialSite': 'https://www.netflix.com/'},
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 336993, 'imdb': 'tt7570990'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/133/332859.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/133/332859.jpg'},
#    'summary': '<p>Hosted by writer, producer, actor and super fan Jim Rash, <b>Beyond Stranger Things</b> tackles inspiration for the series, behind-the-scenes stories, and analyzes every aspect of the second season – answering all the burning questions.</p><p>The series features Stranger Things creators Matt and Ross Duffer, executive producer Shawn Levy, and the cast -- Sean Astin, Linnea Berthelsen, Millie Bobby Brown, Natalia Dyer, Brett Gelman, David Harbour, Randy Havens (the teacher!), Charlie Heaton, Joe Keery, Gaten Matarazzo, Caleb McLaughlin, Dacre Montgomery, Paul Reiser, Noah Schnapp, Sadie Sink, and Finn Wolfhard, along with special guests!</p>',
#    'updated': 1600467178,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/32942'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/1341527'}}}},
#  {'score': 0.56895006,
#   'show': {'id': 46081,
#    'url': 'https://www.tvmaze.com/shows/46081/stranger-among-us',
#    'name': 'Stranger Among Us',
#    'type': 'Documentary',
#    'language': 'English',
#    'genres': ['Crime'],
#    'status': 'Running',
#    'runtime': 60,
#    'averageRuntime': 60,
#    'premiered': '2020-01-27',
#    'ended': None,
#    'officialSite': 'https://www.investigationdiscovery.com/tv-shows/stranger-among-us/',
#    'schedule': {'time': '22:00', 'days': ['Monday']},
#    'rating': {'average': None},
#    'weight': 45,
#    'network': {'id': 89,
#     'name': 'Investigation Discovery',
#     'country': {'name': 'United States',
#      'code': 'US',
#      'timezone': 'America/New_York'},
#     'officialSite': None},
#    'webChannel': None,
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 376380, 'imdb': None},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/382/957217.jpg',
#     'original': 'https://static.tvmaze.com/uploads/images/original_untouched/382/957217.jpg'},
#    'summary': '<p><b>Stranger Among Us</b> tells the twisted-but-true stories of established communities and social circles turned upside down by the presence of a single newcomer, leading to murders that slowly reveal not everyone is who they seem.</p>',
#    'updated': 1639331097,
#    '_links': {'self': {'href': 'https://api.tvmaze.com/shows/46081'},
#     'previousepisode': {'href': 'https://api.tvmaze.com/episodes/1811537'}}}}]

# %%
tvmaze_df = pd.DataFrame.from_dict(pd.json_normalize(movie), orient='columns')
tvmaze_df
# Out:
#       score  show.id                                           show.url  \
# 0  0.887987    28517        https://www.tvmaze.com/shows/28517/stranger
# 1  0.700079     2993  https://www.tvmaze.com/shows/2993/stranger-things
# 2  0.697352    40648    https://www.tvmaze.com/shows/40648/the-stranger
# 3  0.688138     7367  https://www.tvmaze.com/shows/7367/doctor-stranger
# 4  0.664883    43944    https://www.tvmaze.com/shows/43944/the-stranger
# 5  0.659943    48779  https://www.tvmaze.com/shows/48779/hello-stranger
# 6  0.640207    46232    https://www.tvmaze.com/shows/46232/the-stranger
# 7  0.589735    33545  https://www.tvmaze.com/shows/33545/hello-stranger
# 8  0.571860    32942  https://www.tvmaze.com/shows/32942/beyond-stra...
# 9  0.568950    46081  https://www.tvmaze.com/shows/46081/stranger-am...
#
#                 show.name    show.type show.language  \
# 0                Stranger     Scripted        Korean
# 1         Stranger Things     Scripted       English
# 2            The Stranger     Scripted       English
# 3         Doctor Stranger     Scripted        Korean
# 4            The Stranger     Scripted       English
# 5          Hello Stranger     Scripted       Tagalog
# 6            The Stranger     Scripted       English
# 7          Hello Stranger  Documentary       English
# 8  Beyond Stranger Things    Talk Show       English
# 9       Stranger Among Us  Documentary       English
#
#                         show.genres show.status  show.runtime  \
# 0        [Crime, Thriller, Mystery]       Ended          90.0
# 1  [Drama, Horror, Science-Fiction]     Running           NaN
# 2          [Drama, Crime, Thriller]       Ended           NaN
# 3         [Drama, Romance, Medical]       Ended          70.0
# 4                        [Thriller]       Ended          10.0
# 5                  [Drama, Romance]       Ended          30.0
# 6          [Drama, Science-Fiction]       Ended          30.0
# 7                                []       Ended          20.0
# 8                          [Comedy]       Ended           NaN
# 9                           [Crime]     Running          60.0
#
#    show.averageRuntime  ...  \
# 0                   83  ...
# 1                   62  ...
# 2                   46  ...
# 3                   65  ...
# 4                    8  ...
# 5                   20  ...
# 6                   30  ...
# 7                   20  ...
# 8                   21  ...
# 9                   60  ...
#
#                                  show.image.original  \
# 0  https://static.tvmaze.com/uploads/images/origi...
# 1  https://static.tvmaze.com/uploads/images/origi...
# 2  https://static.tvmaze.com/uploads/images/origi...
# 3  https://static.tvmaze.com/uploads/images/origi...
# 4  https://static.tvmaze.com/uploads/images/origi...
# 5  https://static.tvmaze.com/uploads/images/origi...
# 6  https://static.tvmaze.com/uploads/images/origi...
# 7  https://static.tvmaze.com/uploads/images/origi...
# 8  https://static.tvmaze.com/uploads/images/origi...
# 9  https://static.tvmaze.com/uploads/images/origi...
#
#                                         show.summary show.updated  \
# 0  <p>Though he is rational, a childhood brain su...   1647029285
# 1  <p>A love letter to the '80s classics that cap...   1667829326
# 2  <p><b>The Stranger</b> follows Adam Price as a...   1618775624
# 3  <p>The series will revolve around Park Hoon, a...   1574971189
# 4  <p>An unassuming young rideshare driver is thr...   1628841352
# 5  <p>What if you meet someone who changes your l...   1641771386
# 6  <p>When a mysterious stranger appears on a fam...   1581669681
# 7  <p><b>Hello Stranger</b> is a contemporary sna...   1569556970
# 8  <p>Hosted by writer, producer, actor and super...   1600467178
# 9  <p><b>Stranger Among Us</b> tells the twisted-...   1639331097
#
#                 show._links.self.href  \
# 0  https://api.tvmaze.com/shows/28517
# 1   https://api.tvmaze.com/shows/2993
# 2  https://api.tvmaze.com/shows/40648
# 3   https://api.tvmaze.com/shows/7367
# 4  https://api.tvmaze.com/shows/43944
# 5  https://api.tvmaze.com/shows/48779
# 6  https://api.tvmaze.com/shows/46232
# 7  https://api.tvmaze.com/shows/33545
# 8  https://api.tvmaze.com/shows/32942
# 9  https://api.tvmaze.com/shows/46081
#
#           show._links.previousepisode.href  show.network  show.webChannel.id  \
# 0  https://api.tvmaze.com/episodes/1914771           NaN                 NaN
# 1  https://api.tvmaze.com/episodes/2209857           NaN                 1.0
# 2  https://api.tvmaze.com/episodes/1772516           NaN                 1.0
# 3   https://api.tvmaze.com/episodes/419817           NaN                 NaN
# 4  https://api.tvmaze.com/episodes/1846826           NaN               325.0
# 5  https://api.tvmaze.com/episodes/1891702           NaN                21.0
# 6  https://api.tvmaze.com/episodes/1800893           NaN                 NaN
# 7  https://api.tvmaze.com/episodes/1362501           NaN                 NaN
# 8  https://api.tvmaze.com/episodes/1341527           NaN                 1.0
# 9  https://api.tvmaze.com/episodes/1811537           NaN                 NaN
#
#    show.webChannel.name show.webChannel.country show.webChannel.officialSite
# 0                   NaN                     NaN                          NaN
# 1               Netflix                     NaN     https://www.netflix.com/
# 2               Netflix                     NaN     https://www.netflix.com/
# 3                   NaN                     NaN                          NaN
# 4                 Quibi                     NaN                         None
# 5               YouTube                     NaN      https://www.youtube.com
# 6                   NaN                     NaN                          NaN
# 7                   NaN                     NaN                          NaN
# 8               Netflix                     NaN     https://www.netflix.com/
# 9                   NaN                     NaN                          NaN
#
# [10 rows x 39 columns]

# %%
pd.DataFrame(tvmaze_df).to_csv("tvmaze_sample.csv")

# %%
print(f'The director of Aliens was {movie["Director"]}.')
# Out:
# The director of Aliens was James Cameron.

# %%
# What was the movie Gladiator rated?
movie = requests.get(url + "Gladiator").json()
print(f'The rating of Gladiator was {movie["Rated"]}.')
# Out:
# The rating of Gladiator was R.

# %%
# What year was 50 First Dates released?
movie = requests.get(url + "50 First Dates").json()
print(f'The movie 50 First Dates was released in {movie["Year"]}.')
# Out:
# The movie 50 First Dates was released in 2004.

# %%
# Who wrote Moana?
movie = requests.get(url + "Moana").json()
print(f'Moana was written by {movie["Writer"]}.')
# Out:
# Moana was written by Jared Bush (screenplay by), Ron Clements (story by), John Musker (story by), Chris Williams (story by), Don Hall (story by), Pamela Ribon (story by), Aaron Kandell (story by), Jordan Kandell (story by).

# %%
# What was the plot of the movie Sing?
movie = requests.get(url + "Sing").json()
print(f'The plot of Sing was: {movie["Plot"]}')
# Out:
# The plot of Sing was: In a city of humanoid animals, a hustling theater impresario's attempt to save his theater with a singing competition becomes grander than he anticipates even as its finalists' find that their lives will never be the same.
